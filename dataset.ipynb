# %% [markdown]
# Evaluation을 위한 테스트 용 Dataset을 Langsmith에 업로드하기.

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langsmith import Client

print("=== 시작 ===")

examples = [
    {
        "inputs": {"input_question": "말이 너무 많으면 문제가 돼?"},
        "outputs":{"answer": """《논어》 爲政篇 13
「先行其言 而後從之」 : 선행기언 이후종지  
"군자는 말보다 먼저 행동하고, 그 다음에 말이 따른다."

《논어》 爲政篇 10
「視其所以 觀其所由 察其所安」 : 시기소이 관기소유 찰기소안 
"그가 무엇을 하는지, 왜 하는지, 무엇을 편안히 여기는지 보아라."

《논어》 里仁篇 24
「君子欲訥於言而敏於行」 : 군자욕눌어언 이민어행  
"군자는 말은 더디게 하고, 행동은 민첩하게 한다."


이를 토대로 생각해 보면,  

말은 누구나 할 수 있지만 말의 진정성을 보증하는 것은 행동이며, 
말 뿐인 사람보다 약속을 실행하는 사람에게서 비로소 믿음이 생겨나는 것입니다.

행동이 없는 말은 공허하지만, 말보다 앞선 행동은 사람들에게 깊은 설득력을 줍니다. 
말이 빠른 사람은 화려해 보이지만, 행동이 빠른 사람은 신뢰를 얻습니다.

군자의 품격은 웅변이 아니라 실행력에서 완성됩니다. 
말한 만큼 실행하는 사람이 되지 않으면 신뢰를 얻지 못할 수 있겠지요.
"""},

        "metadata":{
        "contexts": """《논어》 爲政篇 13 「先行其言 而後從之」
《논어》 爲政篇 10 「視其所以 觀其所由 察其所安」
《논어》 里仁篇 24 「君子欲訥於言而敏於行」"""
},

    },
    {
        "inputs": {"input_question": "잘못을 저질렀는데 어떤 태도를 취해야할까?"},
        "outputs":{"answer": """
《논어》 衛靈公篇 29
「過而不改 是謂過矣」 과이불개 시위과의  
"잘못이 있어도 고치지 않는 것, 이것이 바로 잘못이다."

《논어》 衛靈公篇 26
「小不忍 則亂大謀」 소불인 즉난대모  
"작은 것을 참지 못하면 큰일을 그르친다."

《논어》 衛靈公篇 30 
「吾嘗終日不食 終夜不寢 以思無益 不如學也」 오상종일불식 종야불침 이사무익 불여학야 
"하루 종일 먹지 않고 밤새도록 사색해 보았지만, 사색만으로는 유익함이 없고 배우는 것만 못했다."


이를 토대로 생각해 보면,

우선, 잘못을 인정하기 위해서는 감정적 자존심이나 순간의 부끄러움을 참아낼 수 있는 절제가 필요합니다. 
감정에 휘둘리면 올바른 판단을 잃게 되므로, 차분히 자신을 돌아보는 자세가 중요합니다. 

또한, 실수를 인정하고 고치는 태도가 진정한 성장의 출발점입니다.  
실수를 고친다는 것은 단순히 반성하는 데 그치지 않고, 같은 일이 반복되지 않도록 배움으로 이어지는 반성+배움+개선의 과정입니다.

즉, 잘못을 저질렀을 때에는 실수를 인정하고 감정을 절제하며, 같은 실수를 반복하지 않으려 노력하는 태도가 중요합니다.
"""
},

        "metadata":{
        "contexts": """《논어》 衛靈公篇 29 「過而不改 是謂過矣」
《논어》 衛靈公篇 26 「小不忍 則亂大謀」
《논어》 衛靈公篇 30 「吾嘗終日不食 終夜不寢 以思無益 不如學也」"""
},

    },
    {
        "inputs": {"input_question": "잘하고 싶어서 마음이 너무 조급해. 그런데도 유튜브 쇼츠만 보며 인스턴트 쾌락을 얻고 있네."},
        "outputs":{"answer": """
《논어》 子路篇 17
「無欲速 無見小利 欲速則不達 見小利則大事不成」 무욕속 무견소리, 욕속즉불달, 견소리즉대사불성  
"빨리 이루려 하지 말고, 작은 이익을 좇지 말라.  
빨리 이루려 하면 도달하지 못하고, 작은 이익을 좇으면 큰일이 이루어지지 않는다."

《논어》 衛靈公篇 11
「人無遠慮 必有近憂」 : 인무원려 필유근우  
"멀리 내다보지 않으면, 가까운 근심이 생긴다."

《논어》 衛靈公篇 26
「小不忍 則亂大謀」 : 소불인 즉난대모  
"작은 것을 참지 못하면 큰일을 그르친다."


이를 토대로 생각해 보면,

지금 조급함 속에서 유튜브 쇼츠 같은 즉각적 쾌락을 찾는 마음은 논어에서 말한 ‘작은 이익(小利)’을 좇는 것과 비슷합니다. 
짧은 즐거움은 스트레스를 잊게 하지만 큰 목표를 향한 집중력과 시간을 빼앗습니다.

공자는 ‘빨리 이루려는 마음(欲速)’이 오히려 도달을 방해하고, 작은 보상에 집착하면 큰일을 이루지 못한다고 했습니다. 
따라서 지금 필요한 것은 조급함을 다스리는 인내와 순간적 자극을 통제하는 절제입니다.

즉각적 쾌락을 조금만 줄이고 큰 목표에 다시 시간을 돌린다면, 당신이 원하는 일은 서서히 현실이 될 것입니다. 
큰일은 조급함이 아니라 꾸준함과 넓은 시야에서 이루어진다는 점을 기억하면 좋겠습니다.
"""},

        "metadata":{
        "contexts": """《논어》 子路篇 17 「無欲速 無見小利 欲速則不達 見小利則大事不成」
《논어》 衛靈公篇 11 「人無遠慮 必有近憂」
《논어》 衛靈公篇 26 「小不忍 則亂大謀」"""
},

    },
    {
        "inputs": {"input_question": "어떤 친구가 좋은 친구야?"},
        "outputs":        {"answer": """
《논어》 子張篇 3
「君子尊賢而容衆 嘉善而矜不能」  
: 군자존현 이용중, 가선 이근불능  
"군자는 어진 이를 존중하고, 많은 사람을 포용하며, 선한 사람을 칭찬하고 능하지 못한 이도 불쌍히 여긴다."

《논어》 子路篇 28
「朋友切切偲偲 兄弟怡怡」  
: 붕우절절사사, 형제이이  
"벗과는 서로 진심으로 격려하고 북돋우며, 형제처럼 화합한다."

《논어》 里仁篇 26
「朋友數 斯疏矣」 : 붕우삭 스소의  
"친구에게 지나치게 충고하면 오히려 멀어진다."


이를 토대로 생각해 보면,  

좋은 친구란 서로를 성장시키는 관계입니다. 
공자는 벗이 서로를 진심으로 격려하고(切切偲偲), 함께 조화를 이루며 나아가는 사이이어야 한다고 했습니다. 
또한 군자는 선한 사람과 가까이하고, 능력이 부족한 사람도 포용할 줄 아는 넓은 마음을 가져야 한다고 말합니다.

좋은 친구는 상대의 부족함을 비난하기보다 따뜻함과 배려로 함께 성장을 돕습니다. 
충고가 과하면 관계가 멀어진다고 한 것처럼, 가르치려 드는 태도보다는 서로의 차이를 포용하는 배려가 중요합니다.
"""},

        "metadata":{
        "contexts": """《논어》 子張篇 3 「君子尊賢而容衆 嘉善而矜不能」
《논어》 子路篇 28 「朋友切切偲偲 兄弟怡怡」
《논어》 里仁篇 26 「朋友數 斯疏矣」"""
},

    },
    {
        "inputs": {"input_question": "시험 점수가 너무 낮게 나왔어. 공부를 겉핥기식으로 해서 그런걸까..."},
        "outputs":        {"answer": """
《논어》 學而篇 1
「學而時習之 不亦說乎」 : 학이시습지 불역열호  
"배우고 때때로 익히면 기쁘지 않겠는가."

《논어》 述而篇 15
「吾嘗終日不食 終夜不寢 以思無益 不如學也」  
: 오상종일불식 종야불침 이사무익 불여학야  
"하루 종일 생각만 해도 소용 없으며, 배우는 것만 못하다."

《논어》 爲政篇 15
「學而不思則罔 思而不學則殆」  
: 학이불사즉망 사이불학즉태  
"배우기만 하고 생각하지 않으면 얻는 것이 없고, 생각만 하고 배우지 않으면 위태롭다."


이를 토대로 생각해 보면,

겉핥기식 공부는 지식이 쌓이지 않아 시험에서 실력이 드러나기 어렵습니다.  
공자는 ‘배움과 반복, 그리고 생각의 결합’이 공부의 핵심이라 했습니다.  
단순 암기가 아니라 이해하며 익히는 과정이 필요합니다.  
조급하게 대충 보는 공부가 아니라, 짧아도 집중해 반복하는 학습이 실력을 만듭니다.  
지금의 결과는 부족함을 알려주는 신호일 뿐, 방법을 고치면 점수도 달라질 것입니다.
"""},

        "metadata":{
        "contexts": """《논어》 學而篇 1 「學而時習之 不亦說乎」
《논어》 述而篇 15 「吾嘗終日不食 終夜不寢 以思無益 不如學也」
《논어》 爲政篇 15 「學而不思則罔 思而不學則殆」"""
},
    },
    {
        "inputs": {"input_question": "난 너무 내성적이고 부끄러움이 많아. 내일 수업에서 발표해야 하는데 어떡하지?"},
        "outputs":        {"answer": """
《논어》 公冶長篇 14
「敏而好學 不恥下問」 : 민이호학 불치하문  
"영민하고 배우기를 좋아하며, 아랫사람에게 묻는 것을 부끄러워하지 않았다."

《논어》 衛靈公篇 26
「小不忍 則亂大謀」 : 소불인 즉난대모  
"작은 것을 참지 못하면 큰일을 그르친다."

《논어》 泰伯篇 9
「士不可以不弘毅… 以重其恥」 : 사불가이불홍의 이중기치  
"선비는 넓은 마음과 굳센 의지를 지니고, 부끄러움을 무겁게 여겨야 한다."

《논어》 里仁篇 21
「知者不惑 仁者不憂 勇者不懼」 : 지자불혹 인자불우 용자불구  
"지혜로운 이는 의심하지 않고, 인한 이는 근심하지 않으며, 용기있는 이는 두려워하지 않는다."

이를 토대로 생각해 보면,

공자는 ‘부끄러움’을 숨겨야 할 약점이 아니라 사람을 바르게 세우는 힘이라고 보았습니다.  
부끄러움은 자연스러운 감정이지요. 하지만 작은 두려움을 이겨내지 못하면 더 큰 성장을 놓칠 수 있습니다.  

군자는 행동이 부족한 것을 부끄러워했지, 시도하는 자신을 부끄러워하지 않았습니다.  
발표가 완벽할 필요는 없으며, 내일의 발표는 부끄러움을 힘으로 바꾸는 첫걸음이 될 수 있습니다.  
공자는 묻는 것을 부끄러워하지 않는 태도가 배움의 출발이라고 했듯, 완벽하지 않아도 행동하는 것이 중요합니다.  
용기란 두려움이 없다는 뜻이 아니라, 두려움 속에서도 한 걸음 나아가는 마음입니다.
"""},

        "metadata":{
        "contexts": """《논어》 公冶長篇 14 「敏而好學 不恥下問」
《논어》 衛靈公篇 26 「小不忍 則亂大謀」
《논어》 泰伯篇 9 「士不可以不弘毅… 以重其恥」
《논어》 里仁篇 21 「知者不惑 仁者不憂 勇者不懼」"""
},

    },
    {
        "inputs": {"input_question": "욕심에 대한 논어의 구절들 알아?"},
        "outputs":       {"answer": """
《논어》 季氏篇 7
「其未得之也 患得之 旣得之 患失之」 : 기미득지야 환득지 기득지 환실지  
"얻기 전에는 얻지 못할까 걱정하고, 얻고 나면 잃을까 걱정한다."

《논어》 子路篇 17
「無欲速 無見小利 欲速則不達 見小利則大事不成」  
: 무욕속 무견소리 욕속즉불달 견소리즉대사불성  
"빨리 이루려 하지 말고, 작은 이익을 좇지 말라.  
조급하면 이루지 못하고, 작은 이익에 집착하면 큰일이 이루어지지 않는다."

《논어》 里仁篇 12  
「放於利而行, 多怨」 : 방어리이행 다원  
"이익만 좇아 행동하면 원망을 많이 사게 된다."

《논어》 泰伯篇 9
「士不可以不弘毅… 以重其恥」 : 사불가이불홍의 이중기치  
"선비는 넓은 마음을 지니고, 부끄러움을 무겁게 여겨야 한다."


이를 토대로 생각해 보면,

논어는 욕심을 완전히 금한 것이 아니라, 욕심이 마음을 어지럽히고 방향을 흐릴 때를 경계했습니다.  
작은 이익에 집착하면 큰 목표를 잃고, 얻고 잃는 것에 흔들리면 마음이 계속 불안해집니다.  
공자는 욕심보다 부끄러움을 더 중하게 여기는 사람이 큰 뜻을 이룰 수 있다고 말했습니다.  
이는 사사로운 이익보다 도덕적 부끄러움을 더 중하게 여겨야 한다는 의미로 해석될 수 있겠습니다.

즉, 욕심이 더 큰 가치와 바른 기준에 맞을 수 있도록 조절하는 것은 중요한 덕목입니다.
"""},

        "metadata":{
        "contexts": """《논어》 季氏篇 7 「其未得之也 患得之 旣得之 患失之」
《논어》 子路篇 17 「無欲速 無見小利 欲速則不達 見小利則大事不成」
《논어》 里仁篇 12 「放於利而行 多怨」
《논어》 泰伯篇 9 「士不可以不弘毅… 以重其恥」"""
},

    },
    {
        "inputs": {"input_question": "사람을 판단할 때 무엇을 보아야 할까?"},
        "outputs":        {"answer": """
《논어》 爲政篇 10  
「視其所以 觀其所由 察其所安」 : 시기소이 관기소유 찰기소안  
"그가 무엇을 하는지, 왜 하는지, 무엇을 편안히 여기는지를 보라."

《논어》 宥仁篇 7  
「觀過 斯知仁矣」 : 관과 사지인의  
"그의 허물을 보면 그가 어느 정도 인한지 알 수 있다."

《논어》 憲問篇 02  
「克伐怨欲不行焉, 可以爲仁矣?」 : 극벌원욕 불행언  
"남을 이기려 하고, 자신을 과시하고, 남을 원망하고, 욕심내는 일을 하지 않으면 인하다고 할 수 있습니까?"


이를 토대로 생각해 보면,

공자는 사람을 겉모습이나 말로 판단하지 말고 행동·동기·편안하게 여기는 것을 보라고 했습니다.  
사람이 실수했을 때의 태도와 허물 앞에서의 마음가짐이 그 사람의 깊이를 드러냅니다.  
또한 타인을 이기려 하거나 욕심으로 움직이지 않는가를 살피는 것도 판단의 기준이 됩니다.  
결국 사람을 판단할 때는 겉이 아니라 일관된 행동과 선택의 방향을 보아야 한다고 말할 수 있습니다.
"""},

        "metadata":{
        "contexts": """《논어》 爲政篇 10 「視其所以 觀其所由 察其所安」
《논어》 宥仁篇 7 「觀過 斯知仁矣」
《논어》 憲問篇 2 「克伐怨欲不行焉 可以爲仁矣?」"""
},

    },
    {
        "inputs": {"input_question": "어떻게 해야 사람들과 두루 어울리며 지낼 수 있을까?"},
        "outputs":        {"answer": """
《논어》 爲政篇 14  
「君子周而不比 小人比而不周」 : 군자주이불비 소인비이불주  
"군자는 두루 어울리되 당파를 짓지 않고, 소인은 편을 가르되 두루 어울리지 못한다."

《논어》 顔淵篇 12  
「克己復禮爲仁」 : 극기복례 위인  
"자기를 이기고 예로 돌아가는 것이 인이다."

《논어》 宥仁篇 15  
「忠信以爲質… 愛人」 : 충신이위질 … 애인  
"충성과 믿음을 바탕으로 하고… 사람을 사랑하라."


이를 토대로 생각해 보면,

사람들과 두루 어울리려면 편을 나누지 않는 마음이 가장 중요합니다.  
공자는 군자가 특정 사람만 가르지 않고 모두에게 열린 태도를 가진다고 했습니다. 

또한 예의를 지키고 마음을 다하는 태도와 신뢰를 기본으로 삼을 때 관계는 자연스럽게 조화를 이룹니다.  
결국 두루 어울림은 기술이 아니라 열린 마음·배려·예의에서 시작됩니다.
"""},

        "metadata":{
        "contexts": """《논어》 爲政篇 14 「君子周而不比 小人比而不周」
《논어》 顔淵篇 12 「克己復禮爲仁」
《논어》 宥仁篇 15 「忠信以爲質… 愛人」"""
},

    },
    {
        "inputs": {"input_question": "효도에 대한 구절 찾아줘."},
        "outputs":        {"answer": """
《논어》 爲政篇 5
「生事之以禮 死葬之以禮 祭之以禮」  
: 생사지이례 사장지이례 제지이례  
"살아 계실 때는 예로 섬기고, 돌아가신 후에는 예에 따라 장례하고 제사를 지내라."

《논어》 爲政篇 6
「父母唯其疾之憂」  
: 부모유기질지우  
"부모는 오직 자식이 병들지 않을까 그것만 걱정하신다."

《논어》 爲政篇 7
「今之孝者 是謂能養… 不敬 何以別乎」  
: 금지효자 시위능양… 불경 하이별호  
"요즘 사람들이 말하는 효는 그저 봉양하는 것이라 한다. 그러나 공경함이 없다면 짐승과 무엇이 다르겠는가?"


이를 토대로 생각해 보면,

논어에서 효는 단순한 봉양이 아니라 예(禮)와 공경의 마음을 담아 부모를 모시는 것입니다.  

부모가 자식을 염려하는 마음을 헤아리고, 그 사랑에 예로써 응답하는 태도가 효의 핵심입니다.  
또한 공자는 ‘공경 없는 봉양은 짐승과 다르지 않다’고 하며 효를 마음의 자세로 보았습니다.  
"""},

        "metadata":{
        "contexts": """《논어》 爲政篇 5 「生事之以禮 死葬之以禮 祭之以禮」
《논어》 爲政篇 6 「父母唯其疾之憂」
《논어》 爲政篇 7 「今之孝者 是謂能養… 不敬 何以別乎」"""
},
    },
    {
        "inputs": {"input_question": "국정 운영에 대한 내용은 논어에서 어떤 편에 주로 나와?"},
        "outputs":        {"answer": """
《논어》 爲政篇
「道之以德 齊之以禮 有恥且格」  
: 도지이덕 제지이례 유치차격  
"덕으로 인도하고 예로 다스리면 백성들은 부끄러움을 알고 스스로 바로 선다."

《논어》 爲政篇
「詩三百 一言以蔽之 曰 思無邪」  
: 시삼백 일언이폐지 왈 사무사  
"『시경』 삼백 편을 한마디로 말하면 ‘생각에 거짓됨이 없다’는 것이다."
(정치의 핵심은 올바른 마음가짐이라는 뜻으로 쓰임)

《논어》 學而篇
「君子務本 本立而道生」  
: 군자무본 본립이도생  
"군자는 근본에 힘쓰니, 근본이 바로 서면 올바른 도리가 생긴다."
(국가 운영의 근본을 강조한 구절)


이를 토대로 생각해 보면,

논어에서 ‘나라를 다스리는 법’은 특히 위정편(爲政篇)에 가장 집중적으로 나타납니다.  
이 편에서는 정치의 방법보다 지도자의 덕(德), 예(禮), 마음가짐을 중심으로 설명합니다.  
공자는 제도를 강화하기보다 지도자의 품성과 태도를 정치의 핵심으로 보았습니다.  
정치는 기술이 아니라 사람을 바르게 세우는 도리에서 시작된다고 강조한 것입니다.
"""},

        "metadata":{
        "contexts": """《논어》 爲政篇 「道之以德 齊之以禮 有恥且格」
《논어》 爲政篇 「詩三百 一言以蔽之 曰 思無邪」
《논어》 學而篇 「君子務本 本立而道生」"""
},

    },
]

client = Client()
dataset_name = "analects_dataset"

# Storing inputs in a dataset lets us
# run chains and LLMs over a shared set of examples.
# 난 랭스미스 홈페이지에서 데이터셋(테이블)은 이미 만들어놨으므로 주석처리
# dataset = client.create_dataset(
#   dataset_name=dataset_name, description="",
# )

dataset = client.read_dataset(dataset_name=dataset_name)

# Prepare inputs, outputs, and metadata for bulk creation
client.create_examples(
  dataset_id=dataset.id,
  examples=examples
)

print("analects_dataset 데이터셋에 예제 11개 업로드 완료")
# Out:
# === 시작 ===
# analects_dataset 데이터셋에 예제 11개 업로드 완료
